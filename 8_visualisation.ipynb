# %% [markdown]
# ### MAKING SENSE OF DATA (VISUALISATION)

# %% [markdown]
#  <p></p>
# • Styling your plots <p></p>
# • Creating various advanced visualizations <p></p>

# %% [markdown]
#  #### Controlling the properties of a plot (linewidth,linestyle,color)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# import pandas.tools.rplot as rplot

# %%
x=[1,2,3,4,5]
y=[1,4,9,16,25]

plt.plot(x,y)
plt.show()data:image/png;base64,...

# %%
# supported values are '-', '--', '-.', ':', 'None', ' ', '', 'solid', 'dashed', 'dashdot', 'dotted'

plt.plot(x,y,linewidth=4,linestyle='dashdot',color='r')

# %% [markdown]
# ####  • Combining multiple plots
# #### plt.subplot( m(rows),n(columns),p(place/position) )

# %%
p1 = np.arange(0.0,30,.1)

plt.subplot(2,1,1)
plt.plot(p1,np.sin(p1))#,linewidth=2,linestyle='dashdot',color='green')

plt.subplot(2,1,2)
plt.plot(p1,np.cos(p1),linewidth=2,linestyle='--',color='red')

# %% [markdown]
# ### Playing with text

# %%
n = np.random.random_sample((5,))

# %%
plt.bar(np.arange(len(n)), n,color='red')
plt.xlabel('Indices')
plt.ylabel('Value')
plt.text(1, .7, r'$\mu=' + str(np.round(np.mean(n), 2)) + ' $')
plt.show()

# %%
ax = plt.subplot(212)
ax = plt.subplot(211)
t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line= plt.plot(t, s, lw=2)
plt.annotate('local max', xy=(2, 1), xytext=(3.5, 1.5),arrowprops=dict(facecolor='red', shrink=0.1))
plt.ylim(-2,2)
# plt.show()
# Out:
# (-2, 2)

# %% [markdown]
# ### Styling your plots

# %%
plt.style.use('ggplot')
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.show()

# %%
with plt.style.context(('dark_background')):
    plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.show()

# %%
plt.style.use('fivethirtyeight')
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.show()

# %% [markdown]
# ### Box plots

# %%
## Creating some data
np.random.seed(10)
box_data_1 = np.random.normal(100, 10, 200)
box_data_2 = np.random.normal(80, 30, 200)
box_data_3 = np.random.normal(90, 20, 200)

# %%
# Create the boxplot
bp = plt.boxplot(data_to_plot)

# %%
## add patch_artist=True option to ax.boxplot()
## to get fill color
bp = plt.boxplot(data_to_plot, patch_artist=True)

# %%
## change outline color, fill color and linewidth of the boxes
for box in bp['boxes']:
    # change outline color
    box.set( color='#7570b3', linewidth=2)
    # change fill color
    box.set( facecolor = '#1b9e77' )
    
plt.boxplot(data_to_plot)
#caps,whiskers,medians,fliers can be done too
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fab0bad6b50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fab0b8b2650>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fab0bb02f10>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7fab0bad6c10>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fab0b8a95d0>,
# ...
#  'means': []}

# %% [markdown]
# #### Heatmaps
# A heatmap is a graphical representation where individual values of a matrix are
# represented as colors. A heatmap is very useful in visualizing the concentration of
# values between two dimensions of a matrix. This helps in finding patterns and gives
# a perspective of depth.

# %%
# Generate Data
data = np.random.rand(10,6)
rows = list('ZYXWVUTSRQ') #Xlabel
columns = list('ABCDEF') #Ylabel 
#Basic Heat Map plot
plt.pcolor(data)
plt.show()

# %%
# Add Row/Column Labels
plt.pcolor(data)
plt.xticks(np.arange(0,6)+0.5,columns)
plt.yticks(np.arange(0,10)+0.5,rows)
plt.show()

# %%
# Change color map
plt.pcolor(data,cmap=plt.cm.Reds,edgecolors='k')
plt.xticks(np.arange(0,6)+0.5,columns)
plt.yticks(np.arange(0,10)+0.5,rows)
plt.show()

# %%
# Generate some test data
x = np.random.randn(10000)
y = np.random.randn(10000)
heatmap, xedges, yedges = np.histogram2d(x, y, bins=50)
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]
plt.imshow(heatmap, extent=extent)
plt.show()

# %% [markdown]
# ### Scatter plots with histograms

# %%
df = pd.DataFrame(np.random.randn(1000, 4),
columns=['a', 'b', 'c', 'd'])
spm = pd.plotting.scatter_matrix(df, alpha=0.2,figsize=(6, 6), diagonal='hist')

# %%
spm = pd.plotting.scatter_matrix(df, alpha=0.2,figsize=(6, 6), diagonal='kde')

# %% [markdown]
# ### Area plots

# %%
df = pd.DataFrame(np.random.rand(10, 4),
columns=['p', 'q', 'r', 's'])
df.plot(kind='area');

# %%
df.plot(kind='area', stacked=False);

# %% [markdown]
# ### Bubble plots

# %%
plt.style.use('ggplot')
df = pd.DataFrame(np.random.rand(50, 3), columns=['a', 'b', 'c'])
df.plot(kind='scatter', x='a', y='b', s=df['c']*400 ,color='magenta');

# %% [markdown]
# ### Hexagon bin plots

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])
df['b'] = df['b'] + np.arange(1000)
df.plot(kind='hexbin', x='a', y='b', gridsize=25)

# %% [markdown]
# ### Trellis plots

# %%
#four boxes vala

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='hot')

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.view_init(elev=10., azim=0)
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='hot')

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.view_init(elev=50., azim=0)
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='hot')

# %% [markdown]
# #### Summary
# In this chapter, you learned how to use the various properties of a chart. You
# also learned how to combine multiple charts and style them. There were multiple
# advanced visualizations that you have gained knowledge of through this chapter.
# In the next chapter, we will understand what machine learning is and also explore a
# few machine learning techniques.

# %%
np.random.randn(5)
# Out:
# array([-0.31813424, -0.82979324, -1.43689255, -1.57104396,  0.51858625])
