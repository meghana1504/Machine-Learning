# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot([1,2,3,4],[1,4,9,16])
plt.savefig('plot1.png')

# %%
# x1 = [np.arange(10,60,5)]
# print(x1)
y1 = [np.arange(10,60,5)]
print(y1)
# Out:
# [array([10, 15, 20, 25, 30, 35, 40, 45, 50, 55])]

# %%
p1 = np.arange(0.0,30,.1)

plt.subplot(2,1,1)
plt.plot(p1,np.sin(p1))#,linewidth=2,linestyle='dashdot',color='green')

plt.subplot(2,1,2)
plt.plot(p1,np.cos(p1),linewidth=2,linestyle='--',color='red')

# %%
x1 = np.arange(10,20,0.1)

plt.subplot(2,1,1)
plt.plot(x1,np.sin(x1))

plt.subplot(2,1,2)
plt.plot(x1,np.cos(x1))

# %%
p1 = np.arange(0,60,3)
plt.scatter(p1,np.sin(p1),marker='*')

# %%
def f(x, y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)
X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %%
plt.contour(X, Y, Z, cmap='RdGy')

# %%
plt.style.use('seaborn-white')
data = np.random.randn(1000)
plt.hist(data,color='red');
